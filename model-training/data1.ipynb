# %%
import pandas as pd
df = pd.read_parquet(r"C:\Users\Daniyal Mahar\Desktop\Overtake\Overtake\f1_features.parquet")
display(df)
# Out:
#       Season  RoundNumber                                  OfficialEventName  \
# 0       2022            1         FORMULA 1 GULF AIR BAHRAIN GRAND PRIX 2022
# 1       2022            1         FORMULA 1 GULF AIR BAHRAIN GRAND PRIX 2022
# 2       2022            1         FORMULA 1 GULF AIR BAHRAIN GRAND PRIX 2022
# 3       2022            1         FORMULA 1 GULF AIR BAHRAIN GRAND PRIX 2022
# 4       2022            1         FORMULA 1 GULF AIR BAHRAIN GRAND PRIX 2022
# ...      ...          ...                                                ...
# 1833    2025           24  FORMULA 1 ETIHAD AIRWAYS ABU DHABI GRAND PRIX ...
# 1834    2025           24  FORMULA 1 ETIHAD AIRWAYS ABU DHABI GRAND PRIX ...
# 1835    2025           24  FORMULA 1 ETIHAD AIRWAYS ABU DHABI GRAND PRIX ...
# 1836    2025           24  FORMULA 1 ETIHAD AIRWAYS ABU DHABI GRAND PRIX ...
# 1837    2025           24  FORMULA 1 ETIHAD AIRWAYS ABU DHABI GRAND PRIX ...
#
# ...
